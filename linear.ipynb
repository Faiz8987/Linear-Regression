# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error

# %%
aa=pd.DataFrame({'area':[1000,1100,1200,1300,1400,1500,1600,1700,1800,2000],'price':[150000,160000,180000,195000,200000,220000,230000,238000,250000,280000,]})

# %%
aa.head()
# Out:
#    area   price
# 0  1000  150000
# 1  1100  160000
# 2  1200  180000
# 3  1300  195000
# 4  1400  200000

# %%
sns.scatterplot(x=aa['area'],y=aa['price'],markers='+',s=56,color='brown')
plt.plot(aa['area'],ss)
plt.show()

# %%
reg.fit(np.array(aa['area']).reshape(-1,1),np.array(aa['price']).reshape(-1,1))
# Out:
# LinearRegression()

# %%
reg.predict([[2500]])
# Out:
# array([[342798.7012987]])

# %%
ss=reg.predict(np.array(aa['area']).reshape(-1,1))

# %%
mean_squared_error(aa['price'],ss)
# Out:
# 11026623.376623388

# %%
dd=aa.drop('area',axis='columns')

# %%
dd['gh']=ss

# %%
dd
# Out:
#     price             gh
# 0  150000  151694.805195
# 1  160000  164435.064935
# 2  180000  177175.324675
# 3  195000  189915.584416
# 4  200000  202655.844156
# 5  220000  215396.103896
# 6  230000  228136.363636
# 7  238000  240876.623377
# 8  250000  253616.883117
# 9  280000  279097.402597

# %%
can=pd.read_csv("C:\\Users\\lenovo\\Downloads\\canada_per_capita_income.csv")

# %%
can.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
sns.scatterplot(x=can['year'],y=can['per capita income (US$)'])

plt.show()

# %%
reg.fit(np.array(can['year']).reshape(-1,1),np.array(can['per capita income (US$)']).reshape(-1,1))
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([[41288.69409442]])

# %%
prr=reg.predict(np.array(can['per capita income (US$)']).reshape(-1,1))

# %%
year=can.drop('year',axis='columns')

# %%
year['pred']=prr

# %%
iris=pd.read_csv('iris.data.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x=iris['petal_length'],y=iris['petal_width'])
plt.plot(a_train,b_train_pre)
plt.show()

# %%
x=np.array(iris['petal_length']).reshape(-1,1)

# %%
y=np.array(iris['petal_width']).reshape(-1,1)

# %%
reg=LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[1.7]])
# Out:
# array([[0.34139848]])

# %%
a_train,a_test,b_train,b_test=train_test_split(x,y,test_size=0.3)

# %%
b_train_pre=reg.predict(a_train)

# %%
mean_squared_error(b_train,b_train_pre)
# Out:
# 0.042381569946763384

# %%
qq=iris.drop('sepal_length',axis=1)

# %%
ee=qq.drop('species',axis='columns')

# %%
ww=iris['sepal_length']

# %%
reg.fit(ee,ww)
# Out:
# LinearRegression()

# %%
reg.predict([[3.9,1.5,0.3]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.29685536])

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
l_train,l_test,k_train,k_test=train_test_split(ee,ww,test_size=0.3)

# %%
reg.fit(l_train,k_train)
# Out:
# LinearRegression()

# %%
k_train_pre=reg.predict(l_train)

# %%
mean_squared_error(k_train,k_train_pre)
# Out:
# 0.093214583183325
